# %%
x=input('enter name : ')
i=0
while i<len(x):
    if x[i]=='a' or x[i]=='A':
        print('* * * *')
        print('*     *')
        print('*     *')
        print('* * * *')
        print('*     *\n')
    elif x[i]=='b' or x[i]=='B':
        print('* * * *')
        print('*    *')
        print('* * *')
        print('*    *')
        print('* * * *\n')
    elif x[i]=='c' or x[i]=='C':
        print('* * *')
        print('*   ') 
        print('*   ')
        print('* * *\n')
    elif x[i]=='d' or x[i]=='D':
        print('* * ')
        print('*   *')
        print('*   *')
        print('* *\n')
    elif x[i]=='e' or x[i]=='E':
        print('* * *')
        print('* ')
        print('* * *')
        print('* ')
        print('* * *\n')
    elif x[i]=='f' or x[i]=='F':
        print('* * *')
        print('* ')
        print('* * *')
        print('* ')
        print('*\n')
    elif x[i]=='g' or x[i]=='G':
        print('* * * *')
        print('* ')
        print('*    * * *')
        print('* * *    *\n')
    elif x[i]=='h' or x[i]=='H':
        print('*   *')
        print('*   *')
        print('* * *')
        print('*   *')
        print('*   *\n')
    elif x[i]=='i' or x[i]=='I':
        print('* * * *')
        print('   *   ')
        print('   *   ')
        print('   *   ')
        print('* * * *\n')
    elif x[i]=='j' or x[i]=='J':
        print(' * * *')
        print('     *')
        print('     *')
        print('  *  *')
        print('   * *\n')
    elif x[i]=='k' or x[i]=='K':
        print('*   *')
        print('* *')
        print('*')
        print('* *')
        print('*   *\n')
    elif x[i]=='L' or x[i]=='l':
        print('* ')
        print('*')
        print('*')
        print('* * * *\n')
    elif x[i]=='m' or x[i]=='M':
        print('*       *')
        print('* *  *  *')
        print('*   *   *')
        print('*       *')
        print('*       *\n')
    elif x[i]=='n' or x[i]=='N':
        print('*       *')
        print('* *     *')
        print('*   *   *')
        print('*     * *')
        print('*       *\n')
    elif x[i]=='o' or x[i]=='O':
        print('   *    ')
        print('*     *')
        print('*     *')
        print('   *\n')
    elif x[i]=='p' or x[i]=='P':
        print('* * *')
        print('*   *')
        print('* * *')
        print('*')
        print('*\n')
    elif x[i]=='q' or x[i]=='Q':
        print('   *    ')
        print('*     *')
        print('*     *')
        print('   *')
        print('      *\n')
    elif x[i]=='r'or x[i]=='R':
        print('* * * * ')
        print('*    *')
        print('*  *')
        print('*    *')
        print('*      *\n')
    elif x[i]=='s'or x[i]=='S': 
        print('  * *  ')
        print('*    ')
        print('  *')
        print('    *')
        print('*  *\n ')
    elif x[i]=='t'or x[i]=='T':
        print('* * * * * ')
        print('    *')
        print('    *')
        print('    *\n')
    elif x[i]=='u'or x[i]=='U':
        print('*        * ')
        print('*        *')
        print(' *     *')
        print('   ***\n')
    elif x[i]=='v'or x[i]=='V':
        print('*         * ')
        print(' *       *')
        print('  *     *')
        print('   *   *')
        print('     *\n')
    elif x[i]=='w' or x[i]=='W':
        print('*          *           *')
        print(' *       *  *         *')
        print('  *     *     *      *')
        print('   *   *        *   *')
        print('     *            *\n')
    elif x[i]=='X' or x[i]=='x':
        print(' *        *')
        print('   *    *')
        print('      *')
        print('   *    *')
        print(' *         *\n')
    elif x[i]=='y' or x[i]=='Y':
        print('*       *')
        print('  *   *')
        print('    *')
        print('    *')
        print('    * \n')
    elif x[i]=='z' or x[i]=='Z':
        print('* * * * *')
        print('      *')
        print('    *')
        print('  *')
        print('* * * * *\n')
    i=i+1
# Out:
# enter name : vinay mani
# *         *
#  *       *
#   *     *
#    *   *
#      *
#
# * * * *
#    *
#    *
#    *
# * * * *
#
# *       *
# * *     *
# *   *   *
# *     * *
# *       *
#
# * * * *
# *     *
# *     *
# * * * *
# *     *
#
# *       *
#   *   *
#     *
#     *
#     *
#
# *       *
# * *  *  *
# *   *   *
# *       *
# *       *
#
# * * * *
# *     *
# *     *
# * * * *
# *     *
#
# *       *
# * *     *
# *   *   *
# *     * *
# *       *
#
# * * * *
#    *
#    *
#    *
# * * * *
